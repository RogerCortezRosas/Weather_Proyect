# %%
import os
import pandas as pd
import zipfile

# %%
# Extract zip file 

zip_path =  "c:/Users/rogel/Documents/GitHub/Weather_Proyect/data/weather.zip"
extract_path = 'c:/Users/rogel/Documents/GitHub/Weather_Proyect/data'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %% [markdown]
# ## Transformations

# %%
path = 'c:/Users/rogel/Documents/GitHub/Weather_Proyect/data'
city_df = pd.read_csv(f'{path}/city_attributes.csv')
humidity_df = pd.read_csv(f'{path}/humidity.csv')
pressure_df = pd.read_csv(f'{path}/pressure.csv')
temperature_df = pd.read_csv(f'{path}/temperature.csv')
weatherDes_df = pd.read_csv(f'{path}/weather_description.csv')
windDir_df = pd.read_csv(f'{path}/wind_direction.csv')
wind_speed_df = pd.read_csv(f'{path}/wind_speed.csv')

# %%
wind_speed_df.head(5)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2  2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3  2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4  2012-10-01 16:00:00        0.0       0.0            2.0      0.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 2          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 3          0.0        0.0        0.0      2.0          4.0  ...           3.0
# 4          0.0        0.0        0.0      2.0          4.0  ...           3.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %%
humidity_df.head(5)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1         88.0       82.0       22.0     23.0         50.0  ...          71.0
# 2         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 3         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 4         88.0       81.0       21.0     23.0         49.0  ...          69.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %%
import pandas as pd
import re
import pymysql
import pandas as pd
from io import BytesIO
from sqlalchemy import create_engine
import numpy as np

# %%
def load_to_bd(df,name):
    # Datos de conexión a la RDS de Amazon
    host = '127.0.0.1'  # Cambia esto por el endpoint de tu RDS
    port = 3307
    user = 'airflow'  # Cambia esto por tu usuario
    password = 'airflow'  # Cambia esto por tu contraseña
    database = 'airflow'  # Cambia esto por tu base de datos
    engine = None

    try:
        engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')

        df.to_sql(name,con=engine,if_exists='append',index=False)
        return print("Conexión y insercion exitosa a la base de datos RDS MySQL")

        

    

    except pymysql.MySQLError as e:
        print(f"Error al conectar a la base de datos: {e}")
    finally:
        if engine:
            engine.dispose()

# %%
dicc = {
    'Country':city_df,
    'humidity': humidity_df,
    'pressure': pressure_df,
    'temperature': temperature_df,
    'weather_description': weatherDes_df,
    'wind_direction': windDir_df,
    'wind_speed': wind_speed_df
}

# %%
for key,df in dicc.items():
    df['id']= range(1, len(df) + 1)

# %%
for key,df in dicc.items():
    df = df.iloc[0:10, :]
    load_to_bd(df,key)
# Out:
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL
# Conexión y insercion exitosa a la base de datos RDS MySQL

# %% [markdown]
# ## Transform with pandas

# %%
wind_speed_df
# Out:
#                   datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0      2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1      2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2      2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3      2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4      2012-10-01 16:00:00        0.0       0.0            2.0      0.0
# ...                    ...        ...       ...            ...      ...
# 45248  2017-11-29 20:00:00        NaN       2.0            NaN      4.0
# 45249  2017-11-29 21:00:00        NaN       1.0            NaN      5.0
# 45250  2017-11-29 22:00:00        NaN       1.0            NaN      5.0
# 45251  2017-11-29 23:00:00        NaN       2.0            NaN      3.0
# 45252  2017-11-30 00:00:00        NaN       1.0            NaN      4.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
list_tables = []
for key,df in dicc.items():
    list_tables.append(key)

# %%
def read_bd():
    # Datos de conexión a la RDS de Amazon
    host = '127.0.0.1'  # Cambia esto por el endpoint de tu RDS
    port = 3307
    user = 'airflow'  # Cambia esto por tu usuario
    password = 'airflow'  # Cambia esto por tu contraseña
    database = 'airflow'  # Cambia esto por tu base de datos
    engine = None

    try:
        engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')

        
        return engine


    except pymysql.MySQLError as e:
        print(f"Error al conectar a la base de datos: {e}")
    finally:
        if engine:
            engine.dispose()

# %%
engine = read_bd()

# %%
from sqlalchemy import inspect

# Crear un inspector
inspector = inspect(engine)

# Obtener lista de tablas (método actual)
available_tables = inspector.get_table_names()

# %%
dataframes = {}
for table in list_tables:
    if table in available_tables:  # Verificar si la tabla existe
        dataframes[table] = pd.read_sql_table(table, engine)  # Método más específico
    else:
        print(f"Advertencia: La tabla {table} no existe en la base de datos")

# %%
# cambiar el tipo de dato de object a datetime
for key,df in dataframes.items():
    if 'datetime' in df.columns:
        df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
        df.dropna(subset=['datetime'], inplace=True)  # Eliminar filas con fechas no válidas
        df['datetime'] = df['datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')  # Formato de fecha deseado
        dataframes[key] = df  # Actualizar el DataFrame en el diccionario

# %%
#eliminar filas duplicadas
for key,df in dataframes.items():
    df.drop_duplicates(subset=['datetime'], inplace=True)  # Eliminar duplicados basados en la columna 'datetime'
    dataframes[key] = df

# %%
#cambiar los valores Nan por cero
for key,df in dataframes.items():
    df.fillna(0, inplace=True)  # Cambiar NaN a 0
    dataframes[key] = df

# %%
dataframes['humidity'].head(5)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  New York  \
# 0          NaN        NaN        NaN      NaN          NaN  ...       NaN
# 1         88.0       82.0       22.0     23.0         50.0  ...      58.0
# 2         88.0       81.0       21.0     23.0         49.0  ...      57.0
# 3         88.0       81.0       21.0     23.0         49.0  ...      57.0
# 4         88.0       81.0       21.0     23.0         49.0  ...      57.0
#
#    Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  Nahariyya  \
# ...
